# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data.csv')
df
# Out:
#          index  totalviews/channelelapsedtime                 channelId  \
# 0            0                       0.165199  UCdzU3DSGzyWzN2118yd9X9g
# 1            1                       1.133820  UC0UnhAG47DRyVZGVcbhAXhQ
# 2            2                       0.668120  UCXjtAvK5P3wXBGh0vbGylzg
# 3            3                      25.653505  UCeKHMeUlcLNPLCLUfZUQI2w
# 4            4                      52.773778  UCNWPDyaWf2eAHnofFLSnEMg
# ...        ...                            ...                       ...
# 575605  575605                     259.123802  UCoBsEPCif0cJr0XoH9vKVsA
# 575606  575606                       0.322689  UC2AFyZm1gI81faexxhq5Mzg
# 575607  575607                       2.174518  UCXRQyRCOq8SwupXXqQ3mgAA
# 575608  575608                       5.044453  UCtWqVyrfT_CrVeNx0UM4RjQ
# 575609  575609                       2.980623  UCrgYGNrCj4C9imt2NCneznA
#
#         videoCategoryId  channelViewCount  likes/subscriber  \
# ...

# %%
print(df.columns)
# Out:
# Index(['index', 'totalviews/channelelapsedtime', 'channelId',
#        'videoCategoryId', 'channelViewCount', 'likes/subscriber',
#        'views/subscribers', 'videoCount', 'subscriberCount', 'videoId',
#        'dislikes/views', 'channelelapsedtime', 'comments/subscriber',
#        'likes/views', 'channelCommentCount', 'videoViewCount',
#        'likes/dislikes', 'comments/views', 'totvideos/videocount',
#        'elapsedtime', 'videoLikeCount', 'videoDislikeCount',
#        'dislikes/subscriber', 'totviews/totsubs', 'views/elapsedtime',
#        'videoPublished', 'VideoCommentCount'],
#       dtype='object')

# %%
print(np.average(df['videoLikeCount'].to_list()))
# Out:
# 292.15081044457185

# %%
#TEST BULLSHIT
print(sum(df['likes/views'] < 0))
print(sum(df['dislikes/views'] < 0))
print(sum(df['comments/views'] < 0))
# print(df[df['likes/views'] == -1]['views/elapsedtime'] * df[df['likes/views'] == -1]['elapsedtime'])
# Out:
# 11463
# 11463
# 12120

# %%
check = (df['likes/views'] > 0) & (df['dislikes/views'] > 0) & (df['comments/views'] > 0)
print(sum((df[check]['likes/views'] + df[check]['dislikes/views'] + df[check]['comments/views']).to_list()))
# Out:
# 3643.249006985573

# %%
0.001 * 200 + 500/(10**6)
# Out:
# 0.2005

# %%
# sum(((df[check]['likes/views'] + df[check]['dislikes/views'] + df[check]['comments/views']) * df['views/elapsedtime']* df['elapsedtime'] * 0.2005).to_list()
views = df[check]['views/elapsedtime']* df[check]['elapsedtime']
rel_engage = df[check]['likes/views'] + df[check]['dislikes/views'] + df[check]['comments/views']
print(sum((views * rel_engage * 0.2005).to_list()))
print(sum((views * rel_engage * 0.2005).to_list())/4)
# Out:
# 39087555.400499195
# 9771888.850124799

# %%
t = 5 * 365 * 24 * 60

# %%
sum((df['views/elapsedtime']* df['elapsedtime'] / t).to_list())
# Out:
# 12887.504316210045

# %%
views = (df[check]['views/elapsedtime'] * df[check]['elapsedtime'])
st = (df[check]['likes/views'] + df[check]['dislikes/views'] + df[check]['comments/views'])
idk = sum((views * st).to_list())
idk
# Out:
# 194950400.99999598
